# %% [markdown]
# # 1. Getting VizDoom Up and Running

# %%
# !pip install vizdoom
# Out:
# Requirement already satisfied: vizdoom in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from vizdoom) (1.26.4)
# Requirement already satisfied: gymnasium>=0.28.0 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from vizdoom) (0.29.1)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from vizdoom) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)

# %%
# !cd github & git clone https://github.com/mwydmuch/ViZDoom

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('./VizDoom/scenarios/basic.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([50.])

# %%
# Loop through episodes 
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: 97.0
# Result: 9.0
# reward: -4.0
# reward: 99.0
# Result: 95.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# Result: -380.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: 99.0
# Result: -155.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: 97.0
# Result: -85.0
# reward: -4.0
# reward: 99.0
# Result: 95.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: 99.0
# Result: -26.0
# reward: -4.0
# reward: -4.0
# reward: 99.0
# Result: 91.0
# reward: -4.0
# reward: 99.0
# Result: 95.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -9.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: -4.0
# reward: 99.0
# Result: -192.0

# %%
game.close()

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from gym) (3.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\pratyush ranjan\appdata\local\programs\python\python312\lib\site-packages (from gym) (0.0.8)

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2

# %%
game.get_state().screen_buffer.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 game.get_state().screen_buffer.shape
#
# AttributeError: 'NoneType' object has no attribute 'screen_buffer'

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('./VizDoom/scenarios/basic.cfg')
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %% [markdown]
# # 3. View Game State

# %%
env.reset()
# Out:
# array([[[55],
#         [50],
#         [59],
#         ...,
#         [57],
#         [57],
#         [66]],
#
#        [[68],
#         [65],
#         [65],
#         ...,
#         [56],
#         [67],
#         [72]],
#
#        [[49],
#         [79],
#         [66],
#         ...,
#         [79],
#         [51],
#         [29]],
#
#        ...,
#
#        [[75],
#         [63],
#         [62],
#         ...,
#         [44],
#         [71],
#         [60]],
#
#        [[15],
#         [48],
#         [47],
#         ...,
#         [49],
#         [69],
#         [47]],
#
#        [[22],
#         [14],
#         [26],
#         ...,
#         [57],
#         [37],
#         [39]]], dtype=uint8)

# %%
env.close()

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 env_checker.check_env(env)
#
# File c:\Users\Pratyush Ranjan\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\env_checker.py:421, in check_env(env, warn, skip_render_check)
#     406 def check_env(env: gym.Env, warn: bool = True, skip_render_check: bool = True) -> None:
#     407     """
#     408     Check that an environment follows Gym API.
#     409     This is particularly useful when using a custom environment.
#    (...)
#     419         True by default (useful for the CI)
#     420     """
# --> 421     assert isinstance(
#     422         env, gym.Env
#     423     ), "Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/"
#     425     # ============= Check the spaces (observation and action) ================
#     426     _check_spaces(env)
#
# AssertionError: Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/

# %% [markdown]
# # 3. View State

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 4. Setup Callback

# %%
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
# !pip install stable-baselines3[extra]

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './logs/log_basic'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5. Train Model

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
# %pip install 'shimmy>=0.2.1'
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# c:\Users\Pratyush Ranjan\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
print(model.device)
# Out:
# cuda

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_basic\PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.4     |
# |    ep_rew_mean     | -62.5    |
# | time/              |          |
# |    fps             | 35       |
# |    iterations      | 1        |
# |    time_elapsed    | 56       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.4        |
# |    ep_rew_mean          | -82.7       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 2           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008690272 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -6.63e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 974         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00057     |
# |    value_loss           | 2.74e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.1       |
# |    ep_rew_mean          | -63.1      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 3          |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01767613 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.0721     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.71e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.00157    |
# |    value_loss           | 2.97e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | -16.3       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 4           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014905799 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.61e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.0048      |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -31         |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 5           |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020267926 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.73e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00758     |
# |    value_loss           | 3.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.8        |
# |    ep_rew_mean          | -4.5        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 6           |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016559994 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.92e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000581   |
# |    value_loss           | 3.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.5       |
# |    ep_rew_mean          | -44.4      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 7          |
# |    time_elapsed         | 397        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02418161 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.924     |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.51e+03   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.00572    |
# |    value_loss           | 3.18e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18          |
# |    ep_rew_mean          | -4.62       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 8           |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015945572 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 679         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00813     |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.7        |
# |    ep_rew_mean          | -21.7       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 9           |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011369269 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 824         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 1.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | 4.05        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 10          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024246117 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 823         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.009       |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.9        |
# |    ep_rew_mean          | 14.1        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 11          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.036966227 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.29e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00286     |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 7.61        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 12          |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021571979 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 877         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000602   |
# |    value_loss           | 2.47e+03    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 17.3     |
# |    ep_rew_mean          | 1.57     |
# | time/                   |          |
# |    fps                  | 36       |
# |    iterations           | 13       |
# |    time_elapsed         | 733      |
# |    total_timesteps      | 26624    |
# | train/                  |          |
# |    approx_kl            | 0.025635 |
# |    clip_fraction        | 0.181    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.616   |
# |    explained_variance   | 0.616    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 1.15e+03 |
# |    n_updates            | 120      |
# |    policy_gradient_loss | 0.0226   |
# |    value_loss           | 2.97e+03 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.3        |
# |    ep_rew_mean          | 38          |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 14          |
# |    time_elapsed         | 791         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015008548 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.16e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00202     |
# |    value_loss           | 2.92e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.5       |
# |    ep_rew_mean          | 37.1       |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 15         |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.04316799 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.563     |
# |    explained_variance   | 0.592      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.18e+03   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.005      |
# |    value_loss           | 2.84e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | 34.8        |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 16          |
# |    time_elapsed         | 908         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.029109826 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 486         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0396      |
# |    value_loss           | 1.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | 48.5        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 17          |
# |    time_elapsed         | 968         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.039373867 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 766         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00249     |
# |    value_loss           | 1.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.44        |
# |    ep_rew_mean          | 60.2        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 18          |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.042164385 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 565         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0206      |
# |    value_loss           | 1.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 19          |
# |    time_elapsed         | 1085        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.045736156 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 826         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 1.25e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.54        |
# |    ep_rew_mean          | 54.6        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 20          |
# |    time_elapsed         | 1147        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.043936282 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 561         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00279     |
# |    value_loss           | 1.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.58        |
# |    ep_rew_mean          | 59.2        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 21          |
# |    time_elapsed         | 1208        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.055938803 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 417         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.74        |
# |    ep_rew_mean          | 58.5        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 22          |
# |    time_elapsed         | 1271        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.030486407 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 397         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00454     |
# |    value_loss           | 863         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 8.35     |
# |    ep_rew_mean          | 60.6     |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 23       |
# |    time_elapsed         | 1335     |
# |    total_timesteps      | 47104    |
# | train/                  |          |
# |    approx_kl            | 0.031917 |
# |    clip_fraction        | 0.239    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.61    |
# |    explained_variance   | 0.826    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 429      |
# |    n_updates            | 220      |
# |    policy_gradient_loss | 0.00175  |
# |    value_loss           | 910      |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28        |
# |    ep_rew_mean          | 78          |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 24          |
# |    time_elapsed         | 1401        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.030433642 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 293         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 902         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.3         |
# |    ep_rew_mean          | 72.3        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 25          |
# |    time_elapsed         | 1467        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.039226957 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 252         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0251      |
# |    value_loss           | 411         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.17        |
# |    ep_rew_mean          | 79          |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 26          |
# |    time_elapsed         | 1532        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.031383213 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 152         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0373      |
# |    value_loss           | 432         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.96        |
# |    ep_rew_mean          | 76.2        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 27          |
# |    time_elapsed         | 1598        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.019466147 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 210         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 363         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.76        |
# |    ep_rew_mean          | 82.3        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 28          |
# |    time_elapsed         | 1667        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.047375932 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 152         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 306         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.64        |
# |    ep_rew_mean          | 83.4        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 29          |
# |    time_elapsed         | 1735        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.021463383 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 60.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0149      |
# |    value_loss           | 227         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.12        |
# |    ep_rew_mean          | 81.5        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 30          |
# |    time_elapsed         | 1804        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.036134988 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 51.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00648     |
# |    value_loss           | 147         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.25        |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 31          |
# |    time_elapsed         | 1878        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.029426925 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.311      |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 40.9        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 94.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.35       |
# |    ep_rew_mean          | 85.4       |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 32         |
# |    time_elapsed         | 1948       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02761187 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.275     |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 33.8       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0207     |
# |    value_loss           | 50.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.33        |
# |    ep_rew_mean          | 85.3        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 33          |
# |    time_elapsed         | 2020        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.017052185 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00346     |
# |    value_loss           | 63.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.2         |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 34          |
# |    time_elapsed         | 2101        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.061283886 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.298      |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.8        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00734     |
# |    value_loss           | 82.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.52        |
# |    ep_rew_mean          | 84.7        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 35          |
# |    time_elapsed         | 2173        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017366296 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.9        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.72        |
# |    ep_rew_mean          | 87.8        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 36          |
# |    time_elapsed         | 2243        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.081732206 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.167      |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 34.1        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 108         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.19       |
# |    ep_rew_mean          | 86.1       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 37         |
# |    time_elapsed         | 2318       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02198296 |
# |    clip_fraction        | 0.0646     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.138     |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.62       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0355     |
# |    value_loss           | 16.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.17        |
# |    ep_rew_mean          | 86          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 38          |
# |    time_elapsed         | 2394        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017690789 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.127      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 30.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00461     |
# |    value_loss           | 41.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01        |
# |    ep_rew_mean          | 86.9        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 39          |
# |    time_elapsed         | 2466        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009393211 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.124      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 25.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0129      |
# |    value_loss           | 18.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.9         |
# |    ep_rew_mean          | 87.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 40          |
# |    time_elapsed         | 2538        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.039500616 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.74        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00539     |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.65        |
# |    ep_rew_mean          | 88.3        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 41          |
# |    time_elapsed         | 2619        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.023382789 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.09       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.28        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0111      |
# |    value_loss           | 46.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.89       |
# |    ep_rew_mean          | 87.3       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 42         |
# |    time_elapsed         | 2712       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00749988 |
# |    clip_fraction        | 0.0605     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0953    |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.93       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.0263     |
# |    value_loss           | 13.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.14        |
# |    ep_rew_mean          | 86.2        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 43          |
# |    time_elapsed         | 2786        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.035325956 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.097      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 31.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0176      |
# |    value_loss           | 24.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.68       |
# |    ep_rew_mean          | 88.1       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 44         |
# |    time_elapsed         | 2876       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.02113713 |
# |    clip_fraction        | 0.0509     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.084     |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.33       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0209     |
# |    value_loss           | 38.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.55        |
# |    ep_rew_mean          | 88.6        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 45          |
# |    time_elapsed         | 2956        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010074906 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0823     |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.8         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00517     |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.14        |
# |    ep_rew_mean          | 86.3        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 46          |
# |    time_elapsed         | 3031        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009774832 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0833     |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.09       |
# |    ep_rew_mean          | 86.4       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 47         |
# |    time_elapsed         | 3108       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.05126421 |
# |    clip_fraction        | 0.0611     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0855    |
# |    explained_variance   | 0.735      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 58.3       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.00245    |
# |    value_loss           | 42         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.81        |
# |    ep_rew_mean          | 87.6        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 48          |
# |    time_elapsed         | 3179        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009894021 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0672     |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.81        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0188      |
# |    value_loss           | 8.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.85        |
# |    ep_rew_mean          | 87.2        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 49          |
# |    time_elapsed         | 3251        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006630069 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.064      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.94        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0071      |
# |    value_loss           | 13.3        |
# -----------------------------------------

# %% [markdown]
# # 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('./train/train_basic/best_model_100000')

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)
# Out:
# c:\Users\Pratyush Ranjan\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\Pratyush Ranjan\AppData\Local\Programs\Python\Python312\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
env.close()

# %%
mean_reward
# Out:
# 87.75

# %%
# model.predict(obs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 model.predict(obs)
#
# NameError: name 'obs' is not defined

# %%
for episode in range(5): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.20)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
# Out:
# Total Reward for episode 95.0 is 0
# Total Reward for episode 91.0 is 1
# Total Reward for episode 79.0 is 2
# Total Reward for episode 67.0 is 3
# Total Reward for episode 75.0 is 4

# %%
env.close()
